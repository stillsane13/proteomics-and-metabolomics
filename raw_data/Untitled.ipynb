# %%
import pandas as pd

df = pd.read_excel("/Users/danilmiloserdov/Desktop/диплом/proteins.xlsx")
df.head()
# Out:
#                                        Protein.Group  Coverage [%]  \
# 0  A0A023I7L8;A0A023I7V4;A0A023I889;A0A023I8F1;A0...             8
# 1                              A0A024R6N5;A0A0G2JRN3             4
# 2                              A0A024R798;A0A088QF11             4
# 3                                         A0A024RAJ6             2
# 4                           A0A024RBE8;F8VVM2;F8VWQ0             7
#
#    Unique peptides  Peptides  Protein.Length  Isoelectric.Point  \
# 0                0         5             226            10.6752
# 1                1         1             418             5.3073
# 2                3         3             704             8.6413
# 3                1         1             556             6.7315
# 4                1         1             361             9.7519
#
#    Molecular.Weight                                        Protein.Ids  \
# 0          24859.25  P00846;A0A023I7L8;A0A023I7V4;A0A023I889;A0A023...
# ...

# %%
metadata = pd.read_excel('/Users/danilmiloserdov/Desktop/диплом/metadata.xlsx')
metadata.head()
# Out:
#    No *组别名称        *样本名称（管壁标记名称） *样本报告名称
# 0   1     C    1 HC-203 m 59 BA6      P1
# 1   2     C   1 HC-203 m 59 BA18      P2
# 2   3     C  1 HC-203 m 59 CB_WM      P3
# 3   4     C     1 MD-09 f 64 BA6      P4
# 4   5     C    1 MD-09 f 64 BA18      P5
